# %%
import pandas as pd
import numpy as np
from herramientas import obtener_resumen_valores_unicos

# %%
df_train = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df_test.head()
# Out:
#      id surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0  1235      no  adult           534053         38.6   40.0              20.0
# 1  1236     yes  adult           528469         38.2  112.0              48.0
# 2  1237     yes  adult           528178         37.7   66.0              12.0
# 3  1238      no  adult           534784         37.1   88.0              20.0
# 4  1239     yes  adult           529840         38.3   50.0              12.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0              normal           normal     normal_pink            less_3_sec
# 1                cool          reduced     bright_pink            more_3_sec
# 2                cool           normal      bright_red            less_3_sec
# 3                cool          reduced   pale_cyanotic            less_3_sec
# 4                 NaN           normal     bright_pink            less_3_sec
#
# ...

# %%
import pandas as pd

# Agrupar por la columna 'temp_of_extremities' y calcular las estadísticas
grouped = df_test.groupby('temp_of_extremities')['rectal_temp']

# Calcular los valores deseados
min_temp = grouped.min()
max_temp = grouped.max()
mean_temp = grouped.mean()
median_temp = grouped.median()

# Mostrar los resultados
result_df = pd.DataFrame({
    'Mínimo': min_temp,
    'Máximo': max_temp,
    'Media': mean_temp,
    'Mediana': median_temp
})

print(result_df)
# Out:
#                      Mínimo  Máximo      Media  Mediana
# temp_of_extremities
# cold                   37.0    40.8  38.459302     38.4
# cool                   36.0    40.8  38.260593     38.2
# normal                 37.0    39.5  38.132323     38.1
# warm                   36.0    40.3  38.109091     38.1

# %%
# Agrupar por la columna 'temp_of_extremities' y calcular las estadísticas
grouped = df_train.groupby('temp_of_extremities')['rectal_temp']

# Calcular los valores deseados
min_temp = grouped.min()
max_temp = grouped.max()
mean_temp = grouped.mean()
median_temp = grouped.median()

# Mostrar los resultados
result_df = pd.DataFrame({
    'Mínimo': min_temp,
    'Máximo': max_temp,
    'Media': mean_temp,
    'Mediana': median_temp
})

print(result_df)
# Out:
#                      Mínimo  Máximo      Media  Mediana
# temp_of_extremities
# cold                   36.0    40.3  38.311570     38.3
# cool                   35.4    40.8  38.214429     38.1
# normal                 36.5    40.3  38.135494     38.1
# warm                   37.0    39.4  38.254902     38.3

# %%
# Utiliza el método replace para hacer el reemplazo
df_train['temp_of_extremities'] = df_train['temp_of_extremities'].replace('cold', 'cool')
df_test['temp_of_extremities'] = df_test['temp_of_extremities'].replace('cold', 'cool')

# %%
# Agrupar por la columna 'temp_of_extremities' y calcular las estadísticas
grouped = df_test.groupby('temp_of_extremities')['rectal_temp']

# Calcular los valores deseados
min_temp = grouped.min()
max_temp = grouped.max()
mean_temp = grouped.mean()
median_temp = grouped.median()

# Mostrar los resultados
result_df = pd.DataFrame({
    'Mínimo': min_temp,
    'Máximo': max_temp,
    'Media': mean_temp,
    'Mediana': median_temp
})

print(result_df)
# Out:
#                      Mínimo  Máximo      Media  Mediana
# temp_of_extremities
# cool                   36.0    40.8  38.291219     38.2
# normal                 37.0    39.5  38.132323     38.1
# warm                   36.0    40.3  38.109091     38.1
